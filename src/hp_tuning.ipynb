# %% [markdown]
# ## Carregamento dos Dados e Preparação do Ambiente

# %% [markdown]
# ### Instalação de Pacotes

# %%
! pip install pandas numpy matplotlib scikit-learn imbalanced-learn xgboost
! pip install mlflow --upgrade
! pip install optuna
! pip install shap
# Out:
# Requirement already satisfied: pandas in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (2.3.3)
# Requirement already satisfied: numpy in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (2.2.6)
# Requirement already satisfied: matplotlib in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (3.10.6)
# Requirement already satisfied: scikit-learn in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (1.7.2)
# Requirement already satisfied: imbalanced-learn in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (0.14.0)
# Requirement already satisfied: xgboost in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (3.1.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from pandas) (2025.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from pandas) (2025.2)
# Requirement already satisfied: cycler>=0.10 in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: contourpy>=1.0.1 in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: pillow>=8 in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: packaging>=20.0 in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: scipy>=1.8.0 in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: nvidia-nccl-cu12 in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from xgboost) (2.28.7)
# Requirement already satisfied: six>=1.5 in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: mlflow in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (3.6.0)
# Requirement already satisfied: mlflow-tracing==3.6.0 in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from mlflow) (3.6.0)
# Requirement already satisfied: Flask<4 in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from mlflow) (3.1.2)
# Requirement already satisfied: graphene<4 in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from mlflow) (3.4.3)
# Requirement already satisfied: numpy<3 in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from mlflow) (2.2.6)
# Requirement already satisfied: scipy<2 in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from mlflow) (1.15.3)
# Requirement already satisfied: pandas<3 in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from mlflow) (2.3.3)
# Requirement already satisfied: cryptography<47,>=43.0.0 in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from mlflow) (46.0.3)
# Requirement already satisfied: gunicorn<24 in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from mlflow) (23.0.0)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from mlflow) (1.4.54)
# Requirement already satisfied: matplotlib<4 in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from mlflow) (3.10.6)
# Requirement already satisfied: Flask-CORS<7 in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from mlflow) (6.0.1)
# Requirement already satisfied: pyarrow<23,>=4.0.0 in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from mlflow) (21.0.0)
# Requirement already satisfied: docker<8,>=4.0.0 in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from mlflow) (7.1.0)
# Requirement already satisfied: huey<3,>=2.5.0 in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from mlflow) (2.5.4)
# Requirement already satisfied: alembic!=1.10.0,<2 in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from mlflow) (1.17.2)
# Requirement already satisfied: scikit-learn<2 in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from mlflow) (1.7.2)
# Requirement already satisfied: mlflow-skinny==3.6.0 in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from mlflow) (3.6.0)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from mlflow-skinny==3.6.0->mlflow) (0.5.3)
# Requirement already satisfied: click<9,>=7.0 in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from mlflow-skinny==3.6.0->mlflow) (8.3.1)
# Requirement already satisfied: pydantic<3,>=2.0.0 in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from mlflow-skinny==3.6.0->mlflow) (2.12.5)
# Requirement already satisfied: requests<3,>=2.17.3 in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from mlflow-skinny==3.6.0->mlflow) (2.32.5)
# Requirement already satisfied: packaging<26 in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from mlflow-skinny==3.6.0->mlflow) (25.0)
# Requirement already satisfied: databricks-sdk<1,>=0.20.0 in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from mlflow-skinny==3.6.0->mlflow) (0.73.0)
# Requirement already satisfied: cachetools<7,>=5.0.0 in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from mlflow-skinny==3.6.0->mlflow) (6.2.0)
# Requirement already satisfied: python-dotenv<2,>=0.19.0 in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from mlflow-skinny==3.6.0->mlflow) (1.2.1)
# Requirement already satisfied: uvicorn<1 in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from mlflow-skinny==3.6.0->mlflow) (0.38.0)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from mlflow-skinny==3.6.0->mlflow) (1.38.0)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from mlflow-skinny==3.6.0->mlflow) (1.38.0)
# Requirement already satisfied: fastapi<1 in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from mlflow-skinny==3.6.0->mlflow) (0.122.0)
# Requirement already satisfied: importlib_metadata!=4.7.0,<9,>=3.7.0 in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from mlflow-skinny==3.6.0->mlflow) (8.7.0)
# Requirement already satisfied: typing-extensions<5,>=4.0.0 in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from mlflow-skinny==3.6.0->mlflow) (4.15.0)
# Requirement already satisfied: gitpython<4,>=3.1.9 in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from mlflow-skinny==3.6.0->mlflow) (3.1.45)
# Requirement already satisfied: pyyaml<7,>=5.1 in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from mlflow-skinny==3.6.0->mlflow) (6.0.3)
# Requirement already satisfied: opentelemetry-proto<3,>=1.9.0 in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from mlflow-skinny==3.6.0->mlflow) (1.38.0)
# Requirement already satisfied: cloudpickle<4 in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from mlflow-skinny==3.6.0->mlflow) (3.1.2)
# Requirement already satisfied: protobuf<7,>=3.12.0 in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from mlflow-skinny==3.6.0->mlflow) (6.32.1)
# Requirement already satisfied: tomli in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from alembic!=1.10.0,<2->mlflow) (2.2.1)
# Requirement already satisfied: Mako in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from alembic!=1.10.0,<2->mlflow) (1.3.10)
# Requirement already satisfied: cffi>=2.0.0 in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from cryptography<47,>=43.0.0->mlflow) (2.0.0)
# Requirement already satisfied: urllib3>=1.26.0 in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from docker<8,>=4.0.0->mlflow) (2.5.0)
# Requirement already satisfied: blinker>=1.9.0 in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from Flask<4->mlflow) (1.9.0)
# Requirement already satisfied: markupsafe>=2.1.1 in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from Flask<4->mlflow) (3.0.3)
# Requirement already satisfied: itsdangerous>=2.2.0 in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from Flask<4->mlflow) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from Flask<4->mlflow) (3.1.6)
# Requirement already satisfied: werkzeug>=3.1.0 in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from Flask<4->mlflow) (3.1.3)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from graphene<4->mlflow) (3.2.0)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from graphene<4->mlflow) (3.2.7)
# Requirement already satisfied: python-dateutil<3,>=2.7.0 in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from graphene<4->mlflow) (2.9.0.post0)
# Requirement already satisfied: cycler>=0.10 in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from matplotlib<4->mlflow) (0.12.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from matplotlib<4->mlflow) (3.2.5)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from matplotlib<4->mlflow) (1.4.9)
# Requirement already satisfied: pillow>=8 in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from matplotlib<4->mlflow) (11.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from matplotlib<4->mlflow) (1.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from matplotlib<4->mlflow) (4.60.1)
# Requirement already satisfied: pytz>=2020.1 in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from pandas<3->mlflow) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from pandas<3->mlflow) (2025.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from scikit-learn<2->mlflow) (3.6.0)
# Requirement already satisfied: joblib>=1.2.0 in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from scikit-learn<2->mlflow) (1.5.2)
# Requirement already satisfied: greenlet!=0.4.17 in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from sqlalchemy<3,>=1.4.0->mlflow) (3.2.4)
# Requirement already satisfied: pycparser in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from cffi>=2.0.0->cryptography<47,>=43.0.0->mlflow) (2.23)
# Requirement already satisfied: google-auth~=2.0 in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==3.6.0->mlflow) (2.41.1)
# Requirement already satisfied: annotated-doc>=0.0.2 in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from fastapi<1->mlflow-skinny==3.6.0->mlflow) (0.0.4)
# Requirement already satisfied: starlette<0.51.0,>=0.40.0 in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from fastapi<1->mlflow-skinny==3.6.0->mlflow) (0.50.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from gitpython<4,>=3.1.9->mlflow-skinny==3.6.0->mlflow) (4.0.12)
# Requirement already satisfied: zipp>=3.20 in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==3.6.0->mlflow) (3.23.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.59b0 in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==3.6.0->mlflow) (0.59b0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from pydantic<3,>=2.0.0->mlflow-skinny==3.6.0->mlflow) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from pydantic<3,>=2.0.0->mlflow-skinny==3.6.0->mlflow) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from pydantic<3,>=2.0.0->mlflow-skinny==3.6.0->mlflow) (0.4.2)
# Requirement already satisfied: six>=1.5 in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from python-dateutil<3,>=2.7.0->graphene<4->mlflow) (1.17.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.6.0->mlflow) (2025.8.3)
# Requirement already satisfied: idna<4,>=2.5 in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.6.0->mlflow) (3.10)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.6.0->mlflow) (3.4.3)
# Requirement already satisfied: h11>=0.8 in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from uvicorn<1->mlflow-skinny==3.6.0->mlflow) (0.16.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==3.6.0->mlflow) (5.0.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.6.0->mlflow) (4.9.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.6.0->mlflow) (0.4.2)
# Requirement already satisfied: anyio<5,>=3.6.2 in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from starlette<0.51.0,>=0.40.0->fastapi<1->mlflow-skinny==3.6.0->mlflow) (4.11.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from anyio<5,>=3.6.2->starlette<0.51.0,>=0.40.0->fastapi<1->mlflow-skinny==3.6.0->mlflow) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from anyio<5,>=3.6.2->starlette<0.51.0,>=0.40.0->fastapi<1->mlflow-skinny==3.6.0->mlflow) (1.3.1)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.6.0->mlflow) (0.6.1)
# Requirement already satisfied: optuna in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (4.6.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from optuna) (1.4.54)
# Requirement already satisfied: alembic>=1.5.0 in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from optuna) (1.17.2)
# Requirement already satisfied: PyYAML in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from optuna) (6.0.3)
# Requirement already satisfied: tqdm in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from optuna) (4.67.1)
# Requirement already satisfied: packaging>=20.0 in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from optuna) (25.0)
# Requirement already satisfied: numpy in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from optuna) (2.2.6)
# Requirement already satisfied: colorlog in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from optuna) (6.10.1)
# Requirement already satisfied: typing-extensions>=4.12 in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from alembic>=1.5.0->optuna) (4.15.0)
# Requirement already satisfied: Mako in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from alembic>=1.5.0->optuna) (1.3.10)
# Requirement already satisfied: tomli in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from alembic>=1.5.0->optuna) (2.2.1)
# Requirement already satisfied: greenlet!=0.4.17 in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from sqlalchemy>=1.4.2->optuna) (3.2.4)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from Mako->alembic>=1.5.0->optuna) (3.0.3)
# Collecting shap
#   Downloading shap-0.49.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 5.2 MB/s eta 0:00:00a 0:00:01
# Collecting numba>=0.54
#   Downloading numba-0.62.1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 4.9 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: scikit-learn in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from shap) (1.7.2)
# Requirement already satisfied: cloudpickle in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from shap) (3.1.2)
# Requirement already satisfied: typing-extensions in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from shap) (4.15.0)
# Requirement already satisfied: numpy in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from shap) (2.2.6)
# Collecting slicer==0.0.8
#   Downloading slicer-0.0.8-py3-none-any.whl (15 kB)
# Requirement already satisfied: pandas in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from shap) (2.3.3)
# Requirement already satisfied: packaging>20.9 in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from shap) (25.0)
# Requirement already satisfied: tqdm>=4.27.0 in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from shap) (4.67.1)
# Requirement already satisfied: scipy in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from shap) (1.15.3)
# Collecting llvmlite<0.46,>=0.45.0dev0
#   Downloading llvmlite-0.45.1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (56.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 7.3 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from pandas->shap) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from pandas->shap) (2025.2)
# Requirement already satisfied: pytz>=2020.1 in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from pandas->shap) (2025.2)
# Requirement already satisfied: joblib>=1.2.0 in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from scikit-learn->shap) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from scikit-learn->shap) (3.6.0)
# Requirement already satisfied: six>=1.5 in /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->shap) (1.17.0)
# Installing collected packages: slicer, llvmlite, numba, shap
# Successfully installed llvmlite-0.45.1 numba-0.62.1 shap-0.49.1 slicer-0.0.8

# %% [markdown]
# ### Importação de Bibliotecas

# %%
from collections import Counter

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import (
    classification_report, f1_score,
    ConfusionMatrixDisplay
)

from xgboost import XGBClassifier

from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from imblearn.pipeline import Pipeline

import optuna
import shap

from utils.visualization import (
    plot_metrics_by_class, print_summary_metrics,
    print_summary_metrics_latex
)

# %% [markdown]
# ### Definição de Constantes Auxiliares

# %%
random_state = 42

test_ratio = 0.15

train_ratio_holdout = 0.70
valid_ratio_holdout = 0.15

numeric_attrs = ["idade_paciente", "dias_sintomas_notificacao"]

# %% [markdown]
# ### Obtenção e análise dos dados

# %%
df_sinan_processed = pd.read_csv("../data/3_gold/dataset-processed.csv")

X = df_sinan_processed.drop("severity", axis=1)
y = df_sinan_processed["severity"]

feature_names = X.columns.tolist()
target_names = ["low_risk", "alarm", "severe"]

y = y.map({name: idx for idx, name in enumerate(target_names)})

# %% [markdown]
# ### Separação do Conjunto de Teste
# Essa separação é realizada independentemente do algoritmo utilizado para particionar os dados entre treino e validação (holdout ou LOOCV).

# %%
X_temp, X_test, y_temp, y_test = train_test_split(X, y, test_size=test_ratio, random_state=random_state, stratify=y)

# %%
# Fazendo a segunda divisão, para gerar o conjunto de treino e validação
final_test_size = valid_ratio_holdout / (train_ratio_holdout + test_ratio)
X_train, X_valid, y_train, y_valid = train_test_split(X_temp, y_temp, test_size=final_test_size, random_state=random_state, stratify=y_temp)

# Normalizando atributos numéricos
for col in numeric_attrs:
    mean = X_train[col].mean()
    std = X_train[col].std()
    X_train[col] = (X_train[col] - mean) / (std + 1e-8)
    X_valid[col] = (X_valid[col] - mean) / (std + 1e-8)
    X_test[col] = (X_test[col] - mean) / (std + 1e-8)

print(f"Conjuntos gerados com as seguintes proporções: ")
print(f"  Treinamento: {X_train.shape}")
print(f"  Validação: {X_valid.shape}")
print(f"  Teste: {X_test.shape}")
# Out:
# Conjuntos gerados com as seguintes proporções:
#   Treinamento: (501841, 42)
#   Validação: (107538, 42)
#   Teste: (107538, 42)

# %%
class_counts = Counter(y_train)

print(f"Distribuição original das classes no conjunto de treinamento: {class_counts}")

under_sampler = RandomUnderSampler(sampling_strategy={0: class_counts[1]}, random_state=random_state)
over_sampler = SMOTE(sampling_strategy={2: class_counts[1]}, random_state=random_state)

pipeline = Pipeline([
    ('under', under_sampler),
    ('over', over_sampler)
])

X_train_resampled, y_train_resampled = pipeline.fit_resample(X_train, y_train)

print(f"Distribuição das classes após amostragem no conjunto de treinamento: {Counter(y_train_resampled)}")
# Out:
# Distribuição original das classes no conjunto de treinamento: Counter({0: 294594, 1: 187280, 2: 19967})
# Distribuição das classes após amostragem no conjunto de treinamento: Counter({0: 187280, 1: 187280, 2: 187280})

# %% [markdown]
# ## Hyperparameter Tuning com Optuna

# %% [markdown]
# ### Definição da Função Objetivo

# %%
def suggest_rf_classifier(trial):
    n_estimators = trial.suggest_int("n_estimators", 100, 1000, step=100)
    max_depth = trial.suggest_int("max_depth", 5, 30, step=5)
    min_samples_split = trial.suggest_int("min_samples_split", 2, 10)
    min_samples_leaf = trial.suggest_int("min_samples_leaf", 1, 5)
    max_features = trial.suggest_categorical("max_features", [None, "sqrt", "log2"])
    class_weight = trial.suggest_categorical("class_weight", [None, "balanced", "balanced_subsample"])
    
    clf = RandomForestClassifier(
        n_estimators=n_estimators,
        max_depth=max_depth,
        min_samples_split=min_samples_split,
        min_samples_leaf=min_samples_leaf,
        max_features=max_features,
        random_state=random_state,
        class_weight=class_weight,
        n_jobs=-1
    )
    return clf

def suggest_xgb_classifier(trial):
    n_estimators = trial.suggest_int("n_estimators", 100, 5000, step=100)
    max_depth = trial.suggest_int("max_depth", 2, 15)
    learning_rate = trial.suggest_float("learning_rate", 0.01, 0.3, step=0.01)
    subsample = trial.suggest_float("subsample", 0.5, 1.0, step=0.1)
    colsample_bytree = trial.suggest_float("colsample_bytree", 0.1, 1.0, step=0.1)
    reg_alpha = trial.suggest_int("reg_alpha", 1, 50)
    reg_lambda = trial.suggest_int("reg_lambda", 1, 50)
    min_child_weight = trial.suggest_int("min_child_weight", 1, 10)
    gamma = trial.suggest_float("gamma", 0, 5, step=0.5)
    
    clf = XGBClassifier(
        n_estimators=n_estimators,
        max_depth=max_depth,
        learning_rate=learning_rate,
        subsample=subsample,
        colsample_bytree=colsample_bytree,
        gamma=gamma,
        random_state=random_state,
        use_label_encoder=False,
        eval_metric='mlogloss',
        reg_alpha=reg_alpha,
        reg_lambda=reg_lambda,
        min_child_weight=min_child_weight,
        tree_model='gpu_hist',
        device='cuda:0',
        predictor='gpu_predictor',
        n_jobs=-1
    )
    return clf

def objective(trial):
    classifier_name = trial.suggest_categorical("classifier", ["RandomForest", "XGBoost"])

    if classifier_name == "RandomForest":
        clf = suggest_rf_classifier(trial)
        clf.fit(X_train_resampled, y_train_resampled)
    else:
        clf = suggest_xgb_classifier(trial)
        clf.fit(X_train_resampled, y_train_resampled)

    y_pred = clf.predict(X_valid)
    f1 = f1_score(y_valid, y_pred, average='macro', zero_division=0)
    return f1

# %%
study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=50)
best_trial = study.best_trial

print("Best trial:")
print(f"  F1 Score: {best_trial.value}")
print("  Params: ")
for key, value in best_trial.params.items():
    print(f"    {key}: {value}")
# Out:
# [I 2025-11-27 17:23:13,798] A new study created in memory with name: no-name-8f65b7c6-9922-4271-95a7-2ba71210453b
# [I 2025-11-27 17:31:26,873] Trial 0 finished with value: 0.4909052318405324 and parameters: {'classifier': 'RandomForest', 'n_estimators': 700, 'max_depth': 10, 'min_samples_split': 4, 'min_samples_leaf': 5, 'max_features': None, 'class_weight': 'balanced_subsample'}. Best is trial 0 with value: 0.4909052318405324.
# /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages/xgboost/training.py:199: UserWarning: [17:31:27] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "predictor", "tree_model", "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages/xgboost/core.py:774: UserWarning: [17:31:33] WARNING: /workspace/src/common/error_msg.cc:62: Falling back to prediction using DMatrix due to mismatched devices. This might lead to higher memory usage and slower performance. XGBoost is running on: cuda:0, while the input data is on: cpu.
# Potential solutions:
# - Use a data structure that matches the device ordinal in the booster.
# - Set the device for booster before call to inplace_predict.
#
# This warning will only be shown once.
#
#   return func(**kwargs)
# [I 2025-11-27 17:31:33,661] Trial 1 finished with value: 0.5352382603141815 and parameters: {'classifier': 'XGBoost', 'n_estimators': 100, 'max_depth': 6, 'learning_rate': 0.23, 'subsample': 0.6, 'colsample_bytree': 0.30000000000000004, 'reg_alpha': 26, 'reg_lambda': 36, 'min_child_weight': 8, 'gamma': 2.5}. Best is trial 1 with value: 0.5352382603141815.
# [I 2025-11-27 17:33:08,799] Trial 2 finished with value: 0.5141895686977052 and parameters: {'classifier': 'RandomForest', 'n_estimators': 100, 'max_depth': 15, 'min_samples_split': 8, 'min_samples_leaf': 4, 'max_features': None, 'class_weight': 'balanced_subsample'}. Best is trial 1 with value: 0.5352382603141815.
# [I 2025-11-27 17:46:26,483] Trial 3 finished with value: 0.5318722352009805 and parameters: {'classifier': 'RandomForest', 'n_estimators': 700, 'max_depth': 30, 'min_samples_split': 5, 'min_samples_leaf': 3, 'max_features': None, 'class_weight': 'balanced'}. Best is trial 1 with value: 0.5352382603141815.
# [W 2025-11-27 18:00:27,009] Trial 4 failed with parameters: {'classifier': 'RandomForest', 'n_estimators': 900, 'max_depth': 30, 'min_samples_split': 3, 'min_samples_leaf': 3, 'max_features': None, 'class_weight': 'balanced_subsample'} because of the following error: KeyboardInterrupt().
# Traceback (most recent call last):
#   File "/home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages/optuna/study/_optimize.py", line 205, in _run_trial
#     value_or_values = func(trial)
#   File "/tmp/ipykernel_551953/3313971863.py", line 57, in objective
#     clf.fit(X_train_resampled, y_train_resampled)
#   File "/home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages/sklearn/base.py", line 1365, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "/home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages/sklearn/ensemble/_forest.py", line 486, in fit
#     trees = Parallel(
#   File "/home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages/sklearn/utils/parallel.py", line 82, in __call__
#     return super().__call__(iterable_with_config_and_warning_filters)
#   File "/home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages/joblib/parallel.py", line 2072, in __call__
#     return output if self.return_generator else list(output)
#   File "/home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages/joblib/parallel.py", line 1682, in _get_outputs
#     yield from self._retrieve()
#   File "/home/gabriel/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages/joblib/parallel.py", line 1800, in _retrieve
#     time.sleep(0.01)
# KeyboardInterrupt
# [W 2025-11-27 18:00:27,023] Trial 4 failed with value None.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 2
#       1 study = optuna.create_study(direction="maximize")
# ----> 2 study.optimize(objective, n_trials=50)
#       3 best_trial = study.best_trial
#       5 print("Best trial:")
#
# File ~/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages/optuna/study/study.py:490, in Study.optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     388 def optimize(
#     389     self,
#     390     func: ObjectiveFuncType,
#    (...)
#     397     show_progress_bar: bool = False,
#     398 ) -> None:
#     399     """Optimize an objective function.
#     400
#     401     Optimization is done by choosing a suitable set of hyperparameter values from a given
#    (...)
#     488             If nested invocation of this method occurs.
#     489     """
# --> 490     _optimize(
#     491         study=self,
#     492         func=func,
#     493         n_trials=n_trials,
#     494         timeout=timeout,
#     495         n_jobs=n_jobs,
#     496         catch=tuple(catch) if isinstance(catch, Iterable) else (catch,),
#     497         callbacks=callbacks,
#     498         gc_after_trial=gc_after_trial,
#     499         show_progress_bar=show_progress_bar,
#     500     )
#
# File ~/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages/optuna/study/_optimize.py:67, in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      65 try:
#      66     if n_jobs == 1:
# ---> 67         _optimize_sequential(
#      68             study,
#      69             func,
#      70             n_trials,
#      71             timeout,
#      72             catch,
#      73             callbacks,
#      74             gc_after_trial,
#      75             reseed_sampler_rng=False,
#      76             time_start=None,
#      77             progress_bar=progress_bar,
#      78         )
#      79     else:
#      80         if n_jobs == -1:
#
# File ~/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages/optuna/study/_optimize.py:164, in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     161         break
#     163 try:
# --> 164     frozen_trial_id = _run_trial(study, func, catch)
#     165 finally:
#     166     # The following line mitigates memory problems that can be occurred in some
#     167     # environments (e.g., services that use computing containers such as GitHub Actions).
#     168     # Please refer to the following PR for further details:
#     169     # https://github.com/optuna/optuna/pull/325.
#     170     if gc_after_trial:
#
# File ~/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages/optuna/study/_optimize.py:262, in _run_trial(study, func, catch)
#     255         assert False, "Should not reach."
#     257 if (
#     258     updated_state == TrialState.FAIL
#     259     and func_err is not None
#     260     and not isinstance(func_err, catch)
#     261 ):
# --> 262     raise func_err
#     263 return trial._trial_id
#
# File ~/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages/optuna/study/_optimize.py:205, in _run_trial(study, func, catch)
#     203 with get_heartbeat_thread(trial._trial_id, study._storage):
#     204     try:
# --> 205         value_or_values = func(trial)
#     206     except exceptions.TrialPruned as e:
#     207         # TODO(mamu): Handle multi-objective cases.
#     208         state = TrialState.PRUNED
#
# Cell In[16], line 57, in objective(trial)
#      55 if classifier_name == "RandomForest":
#      56     clf = suggest_rf_classifier(trial)
# ---> 57     clf.fit(X_train_resampled, y_train_resampled)
#      58 else:
#      59     clf = suggest_xgb_classifier(trial)
#
# File ~/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages/sklearn/base.py:1365, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1358     estimator._validate_params()
#    1360 with config_context(
#    1361     skip_parameter_validation=(
#    1362         prefer_skip_nested_validation or global_skip_validation
#    1363     )
#    1364 ):
# -> 1365     return fit_method(estimator, *args, **kwargs)
#
# File ~/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:486, in BaseForest.fit(self, X, y, sample_weight)
#     475 trees = [
#     476     self._make_estimator(append=False, random_state=random_state)
#     477     for i in range(n_more_estimators)
#     478 ]
#     480 # Parallel loop: we prefer the threading backend as the Cython code
#     481 # for fitting the trees is internally releasing the Python GIL
#     482 # making threading more efficient than multiprocessing in
#     483 # that case. However, for joblib 0.12+ we respect any
#     484 # parallel_backend contexts set at a higher level,
#     485 # since correctness does not rely on using threads.
# --> 486 trees = Parallel(
#     487     n_jobs=self.n_jobs,
#     488     verbose=self.verbose,
#     489     prefer="threads",
#     490 )(
#     491     delayed(_parallel_build_trees)(
#     492         t,
#     493         self.bootstrap,
#     494         X,
#     495         y,
#     496         sample_weight,
#     497         i,
#     498         len(trees),
#     499         verbose=self.verbose,
#     500         class_weight=self.class_weight,
#     501         n_samples_bootstrap=n_samples_bootstrap,
#     502         missing_values_in_feature_mask=missing_values_in_feature_mask,
#     503     )
#     504     for i, t in enumerate(trees)
#     505 )
#     507 # Collect newly grown trees
#     508 self.estimators_.extend(trees)
#
# File ~/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages/sklearn/utils/parallel.py:82, in Parallel.__call__(self, iterable)
#      73 warning_filters = warnings.filters
#      74 iterable_with_config_and_warning_filters = (
#      75     (
#      76         _with_config_and_warning_filters(delayed_func, config, warning_filters),
#    (...)
#      80     for delayed_func, args, kwargs in iterable
#      81 )
# ---> 82 return super().__call__(iterable_with_config_and_warning_filters)
#
# File ~/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages/joblib/parallel.py:2072, in Parallel.__call__(self, iterable)
#    2066 # The first item from the output is blank, but it makes the interpreter
#    2067 # progress until it enters the Try/Except block of the generator and
#    2068 # reaches the first `yield` statement. This starts the asynchronous
#    2069 # dispatch of the tasks to the workers.
#    2070 next(output)
# -> 2072 return output if self.return_generator else list(output)
#
# File ~/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages/joblib/parallel.py:1682, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1679     yield
#    1681     with self._backend.retrieval_context():
# -> 1682         yield from self._retrieve()
#    1684 except GeneratorExit:
#    1685     # The generator has been garbage collected before being fully
#    1686     # consumed. This aborts the remaining tasks if possible and warn
#    1687     # the user if necessary.
#    1688     self._exception = True
#
# File ~/Documents/UFRGS/2025-2/ML/TF/.venv/lib/python3.10/site-packages/joblib/parallel.py:1800, in Parallel._retrieve(self)
#    1789 if self.return_ordered:
#    1790     # Case ordered: wait for completion (or error) of the next job
#    1791     # that have been dispatched and not retrieved yet. If no job
#    (...)
#    1795     # control only have to be done on the amount of time the next
#    1796     # dispatched job is pending.
#    1797     if (nb_jobs == 0) or (
#    1798         self._jobs[0].get_status(timeout=self.timeout) == TASK_PENDING
#    1799     ):
# -> 1800         time.sleep(0.01)
#    1801         continue
#    1803 elif nb_jobs == 0:
#    1804     # Case unordered: jobs are added to the list of jobs to
#    1805     # retrieve `self._jobs` only once completed or in error, which
#    (...)
#    1811     # timeouts before any other dispatched job has completed and
#    1812     # been added to `self._jobs` to be retrieved.
#
# KeyboardInterrupt:

# %%
# Holdout set evaluation
if best_trial.params["classifier"] == "RandomForest":
    best_clf = suggest_rf_classifier(best_trial)
    best_clf.fit(X_train_resampled, y_train_resampled)
else:
    best_clf = suggest_xgb_classifier(best_trial)
    best_clf.fit(X_train_resampled, y_train_resampled, eval_set=[(X_valid, y_valid)], early_stopping_rounds=100, verbose=False)
    
y_pred_test = best_clf.predict(X_test)
print("Relatório de Classificação no Conjunto de Teste:")
print(classification_report(y_test, y_pred_test, target_names=target_names, zero_division=0))

# %%
ConfusionMatrixDisplay.from_predictions(y_test, y_pred_test, display_labels=target_names, cmap=plt.cm.Blues, normalize='true')

plt.savefig("../figures/optimized_clf_confusion_matrix.pdf")
plt.show()

# %%
fig, ax, report_dict = plot_metrics_by_class(y_test, y_pred_test, target_names=target_names)

plt.savefig("../figures/optimized_clf_metrics_by_class.pdf")
plt.show()

# %%
print_summary_metrics(report_dict)

# %%
print_summary_metrics_latex(report_dict)

# %% [markdown]
# ## Interpretação dos Resultados com SHAP

# %%
# Using SHAP to explain the optimized model
explainer = shap.Explainer(best_clf, X_train_resampled)
shap_values = explainer(X_test)

shap.summary_plot(shap_values, X_test, feature_names=feature_names, show=False)
plt.savefig("../figures/optimized_clf_shap_summary_plot.pdf")
plt.show()
